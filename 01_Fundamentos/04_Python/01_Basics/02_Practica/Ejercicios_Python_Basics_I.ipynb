# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
cita = """¿Por qué esta magnífica tecnología científica,
	que ahorra trabajo y nos hace la vida mas fácil,
		nos aporta tan poca felicidad?
			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino."""
print(cita)
print('"Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
nom_calle = input("introduce el nombre de tu calle, sin numero")
num_calle = int(input("Introduce el numero de la calle"))
poblacion = input("Ahora introduce tu poblacion")
codigopostal = int(input("Y por ultimo, tu codigo postal"))
concat = nom_calle + " " + str(num_calle) + ", " + str(codigopostal) + " " + poblacion

print(concat)
# Out:
# Camino de Moncada 104, 46025 Valencia

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
print(input("Introduce el nombre de tu calle") + " " + input("Ahora el numero") + ", " + input("Ahora el codigo postal") + " " + input("¿Y tu población?"))
# Out:
# Camino de Moncada 104, Valencia 46025

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. Correcta
# 2. Incorrecta, porque no cierra las comillas del estring
# 3. Incorrecta, palabra reservada
# 4. Incorrecta, no se pueden usar espacios
# 5. Correcta
# 6. Incorrecta, palabra reservada
# 7. Incorrecta, no se pueden usar numeros al inicio del nombre de la variable
# 8. Correcta

# %%
mi_variable = "Economía"
exec = True
True = "ejercicio"
mi_variable10 = 6
81_mivariable

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
gradosC = float(input("Introduce una temperatura en grados celsius."))
gradosF = float(gradosC / 5) + 32
print("El equivalente en grados Fahrenheit es", gradosF)
# Out:
# El equivalente en grados Fahrenheit es 37.2

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
## Preguntamos al usuario una temperatura, y la convertimos en float, en caso de ser necesarios los decimales
gradosC = float(input("Introduce una temperatura en grados celsius."))

"""
    Aqui realizamos la conversion, siendo la formula:
        Fahrenheit = (Celsius / 5) + 32
    Al haber convertido el input a float directamente, nos ahorramos problemas
"""
gradosF = float(gradosC / 5) + 32

## Printeamos el resultado
print("El equivalente en grados Fahrenheit es", gradosF)
# Out:
# El equivalente en grados Fahrenheit es 36.6
